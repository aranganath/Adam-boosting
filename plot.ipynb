# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle as pkl

with open('./results/quasiAdamWithQLRprelim.pkl', 'rb') as handle:
    a = pkl.load(handle)

with open('./results/quasiAdamWithoutQLRprelim.pkl', 'rb') as handle:
    b = pkl.load(handle)

# with open('./results/quasiAdamWithextraQLR.pkl', 'rb') as handle:
#     c = pkl.load(handle)

# %%
plt.plot(a, label='adam')
plt.plot(b, label='quasiAdam')
plt.xlabel('iterations')
plt.ylabel('loss - Cross-entropy')
plt.legend()
plt.show()
