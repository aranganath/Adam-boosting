# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle as pkl

with open('./results/quasiAdamWithQLR.pkl', 'rb') as handle:
    a = pkl.load(handle)

with open('./results/quasiAdamWithoutQLR.pkl', 'rb') as handle:
    b = pkl.load(handle)

# %%
plt.plot(a, label='adam')
plt.plot(b, label='quasiAdam')
plt.legend()
plt.show()
